# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import numpy as np
from matplotlib import rc

plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
m_df = pd.read_csv('가계부채.csv')
s_df = pd.read_csv('소비.csv')

m_df = m_df.fillna('GDP대비 가계부채 비율')

h_df = s_df.iloc[0]

print(m_df)
print('--------------------')
print(s_df)
# Out:
#               분류    2002    2003    2004    2005    2006    2007    2008  \
# 0           가계신용  464712  472051  494203  542871  607133  665394  723522
# 1           가계대출  416771  445422  468939  514844  575601  630113  683602
# 2           판매신용   47941   26629   25264   28027   31532   35281   39919
# 3  GDP대비 가계부채 비율      59      56      54      57      60      61      63
#
#      2009    2010  ...     2013     2014     2015     2016     2017     2018  \
# 0  775985  843190  ...  1019041  1085259  1203099  1342527  1450627  1536712
# 1  734292  793779  ...   960580  1025076  1137953  1269808  1369837  1446628
# 2   41694   49411  ...    58461    60183    65146    72719    80790    90084
# 3      64      64  ...       68       69       73       77       79       81
#
#       2019     2020     2021     2022
# 0  1600601  1729485  1862908  1867029
# 1  1504882  1633591  1757065  1749292
# 2    95719    95894   105843   117738
# 3       83       89       90       87
#
# ...

# %%
df = pd.read_csv('OECD_가계부채.csv')
df.rename(columns={'Unnamed: 0':'연도'}, inplace=True)
df.set_index('연도', inplace=True)

mask = []
for i in range(13):
    i += 1995
    i = str(i)
    mask.append(i)
    
df.drop(mask, axis=1, inplace=True)
df.dropna(inplace=True)
df = df.T
df_3 = df['한국']
df.drop('한국', axis=1, inplace=True)

# %%
s_df.drop('Unnamed: 0', axis=1, inplace=True)
s_df.drop(0, axis=0, inplace=True)

# %%
s_df.rename(columns={'Unnamed: 1':'분야'}, inplace=True)
s_df.dropna(axis=0, thresh=5, inplace=True)

# %%
s_df.set_index('분야', inplace=True)
s_df
# Out:
#              2003   2004   2005   2006   2007   2008   2009   2010   2011  \
# 분야
# 식료품·비주류음료    15.0   15.1   14.6   14.2   13.8   14.1   13.8   13.9   14.2
# 주류·담배         1.4    1.5    1.5    1.5    1.4    1.3    1.2    1.2    1.2
# 의류·신발         6.6    6.3    6.3    6.3    6.4    6.2    6.1    6.4    6.5
# 주거·수도·광열      9.9    9.7    9.8    9.9    9.7    9.7    9.8   10.1   10.1
# 가정용품·가사서비스    3.5    3.4    3.6    3.5    3.7    3.5    3.6    3.8    3.8
# 보건            5.8    5.7    5.9    6.2    6.4    6.2    6.5    6.7    6.5
# 교통           11.7   11.6   12.0   12.5   12.4   12.4   12.4   11.9   12.3
# 통신            7.4    7.3    7.0    6.8    6.7    6.3    6.2    6.1    6.0
# 오락·문화         5.9    5.5    5.4    5.4    5.3    5.2    5.2    5.5    5.4
# 교육           11.0   11.3   11.3   11.4   11.9   12.8   13.5   13.0   12.3
# 음식·숙박        13.8   14.2   13.8   13.4   13.5   13.6   13.0   12.7   12.5
# 기타 상품·서비스     8.2    8.5    8.6    8.9    8.8    8.7    8.6    8.9    9.2
# ...

# %%
s_df.drop('합계', inplace=True)

# %%
df_1 = s_df.astype(float)
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, 식료품·비주류음료 to 기타 상품·서비스
# Data columns (total 20 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2003    12 non-null     float64
#  1   2004    12 non-null     float64
#  2   2005    12 non-null     float64
#  3   2006    12 non-null     float64
#  4   2007    12 non-null     float64
#  5   2008    12 non-null     float64
#  6   2009    12 non-null     float64
#  7   2010    12 non-null     float64
#  8   2011    12 non-null     float64
#  9   2012    12 non-null     float64
#  10  2013    12 non-null     float64
#  11  2014    12 non-null     float64
#  12  2015    12 non-null     float64
#  13  2016    12 non-null     float64
#  14  2017    12 non-null     float64
#  15  2018    12 non-null     float64
#  16  2019    12 non-null     float64
#  17  2020    12 non-null     float64
#  18  2021    12 non-null     float64
#  19  2022    12 non-null     float64
# dtypes: float64(20)
# ...

# %%
df_1 = df_1.T

# %%
h_df.drop(['Unnamed: 0', 'Unnamed: 1'], inplace=True)
# Out:
# C:\Users\dlwns\AppData\Local\Temp\ipykernel_16756\1589282109.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h_df.drop(['Unnamed: 0', 'Unnamed: 1'], inplace=True)

# %%
m_df
# Out:
#               분류    2002    2003    2004    2005    2006    2007    2008  \
# 0           가계신용  464712  472051  494203  542871  607133  665394  723522
# 1           가계대출  416771  445422  468939  514844  575601  630113  683602
# 2           판매신용   47941   26629   25264   28027   31532   35281   39919
# 3  GDP대비 가계부채 비율      59      56      54      57      60      61      63
#
#      2009    2010  ...     2013     2014     2015     2016     2017     2018  \
# 0  775985  843190  ...  1019041  1085259  1203099  1342527  1450627  1536712
# 1  734292  793779  ...   960580  1025076  1137953  1269808  1369837  1446628
# 2   41694   49411  ...    58461    60183    65146    72719    80790    90084
# 3      64      64  ...       68       69       73       77       79       81
#
#       2019     2020     2021     2022
# 0  1600601  1729485  1862908  1867029
# 1  1504882  1633591  1757065  1749292
# 2    95719    95894   105843   117738
# 3       83       89       90       87
#
# ...

# %%
plt.style.use('ggplot')

fig = plt.figure(figsize=(40, 30))
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

df.plot(linewidth=2, ax=ax1)
df_3.plot(linewidth=5, linestyle='dashdot', color='red', ax=ax1)

ax1.legend(loc='upper left', fontsize=20)
ax1.tick_params(labelsize=20)
ax1.set_title('OECD국가별 소득대비 가계부채 비율 (단위: %)', fontsize=30)

h_df.plot(kind='bar', ax=ax2)
for i in range(16, 19):
    ax2.patches[i].set_color('#79AA8F')
ax2.tick_params(labelsize=20)
ax2.set_title('연도별 소비지출량 (단위: 천원)', size=30)
ax2.set_ylim(0, 3200)

ax2.annotate('', 
             xy=(18, 2560), 
             xytext=(16, 2650), 
             xycoords='data', 
             textcoords='data',
             arrowprops=dict(arrowstyle='->', color='#ED7D24', lw=10))

ax2.annotate('코로나 시작 시기', 
             xy=(15, 2600), 
             rotation=-14,
             xycoords='data', 
             textcoords='data',
             fontsize=25)


df_1.plot(kind='bar', width=0.7,
          stacked=True, ax=ax3)

ax3.legend(loc='upper left', fontsize=20)
ax3.tick_params(labelsize=20)
ax3.set_title('분야별 소비비율(단위: %)', size=30)

df_2 = df_1['보건']
df_2.plot(ax=ax4, linewidth=10)
ax4.scatter(16, 8.2, c='#ED3624', s=400)
ax4.tick_params(labelsize=20)
ax4.set_title('연도별 보건 분야 소비지출 비율', fontsize=30)
ax4.set_ylabel('비율 (단위:%)')

ax4.annotate('코로나 시작 시기', 
             xy=(16, 8.2), 
             xytext=(11, 7.75),
             xycoords='data', 
             textcoords='data',
             fontsize=25,
             arrowprops=dict(arrowstyle='->', color='#ED3624', lw=10))

plt.show()

# %% [markdown]
# <b1></b1>

# %%
df_4 = pd.read_csv('연령별 소득 분포도.csv')
df_4 = df_4.fillna(method='ffill')
df_4.set_index('성별', inplace=True)
df_4
# Out:
# C:\Users\dlwns\AppData\Local\Temp\ipykernel_16756\2898218743.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_4 = df_4.fillna(method='ffill')
#              연령구분별                 분배지표별  2011  2011.1  2012  2012.1  2013  \
# 성별
# 성별           연령구분별                 분배지표별  시장소득  처분가능소득  시장소득  처분가능소득  시장소득
# 전체              전체          균등화 소득평균(만원)  2741    2558  2873    2675  2974
# 전체              전체  상대적빈곤율(중위소득50%이하, %)  19.6    18.6    19    18.3  19.1
# 전체  근로연령인구(18~65세)          균등화 소득평균(만원)  2959    2741  3109    2872  3235
# 전체  근로연령인구(18~65세)  상대적빈곤율(중위소득50%이하, %)  14.1      14  13.8    13.9  13.7
# 전체  은퇴연령인구(66세 이상)          균등화 소득평균(만원)  1401    1594  1498    1702  1568
# 전체  은퇴연령인구(66세 이상)  상대적빈곤율(중위소득50%이하, %)  57.8    47.8  56.7      47  56.9
# 전체    노인인구(65세 이상)          균등화 소득평균(만원)  1425    1628  1541    1750  1608
# ...

# %%
mask1 = df_4['분배지표별'] == '균등화 소득평균(만원)'
df_5 = df_4[mask1]

# %%
df_5.drop('분배지표별', axis=1, inplace=True)
# Out:
# C:\Users\dlwns\AppData\Local\Temp\ipykernel_16756\4163349201.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_5.drop('분배지표별', axis=1, inplace=True)

# %%
df_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, 전체 to 여자
# Data columns (total 23 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연령구분별   12 non-null     object
#  1   2011    12 non-null     object
#  2   2011.1  12 non-null     object
#  3   2012    12 non-null     object
#  4   2012.1  12 non-null     object
#  5   2013    12 non-null     object
#  6   2013.1  12 non-null     object
#  7   2014    12 non-null     object
#  8   2014.1  12 non-null     object
#  9   2015    12 non-null     object
#  10  2015.1  12 non-null     object
#  11  2016    12 non-null     object
#  12  2016.1  12 non-null     object
#  13  2017    12 non-null     object
#  14  2017.1  12 non-null     object
#  15  2018    12 non-null     object
#  16  2018.1  12 non-null     object
#  17  2019    12 non-null     object
#  18  2019.1  12 non-null     object
#  19  2020    12 non-null     object
#  20  2020.1  12 non-null     object
# ...

# %%
mask2 = df_5.index == '전체'
mask3 = df_5.index == '남자'
mask4 = df_5.index == '여자'
df_5_A = df_5[mask2]
df_5_m = df_5[mask3]
df_5_f = df_5[mask4]

# %%
df_5_A = df_5_A.set_index('연령구분별')
df_5_m = df_5_m.set_index('연령구분별')
df_5_f = df_5_f.set_index('연령구분별')

# %%
df_5_A = df_5_A.astype(float)
df_5_m = df_5_m.astype(float)
df_5_f = df_5_f.astype(float)

# %%
df_5_A = df_5_A.T
df_5_f = df_5_f.T
df_5_m = df_5_m.T

# %%
fig1 = plt.figure(figsize=(15, 7))

ax5 = fig1.add_subplot(1, 3, 1)
ax6 = fig1.add_subplot(1, 3, 2)
ax7 = fig1.add_subplot(1, 3, 3)

df_5_A.plot(kind='box', ax=ax5)
df_5_f.plot(kind='box', ax=ax6)
df_5_m.plot(kind='box', ax=ax7)

ax5.set_xticklabels(df_5_A.columns, rotation=75)
ax6.set_xticklabels(df_5_f.columns, rotation=75)
ax7.set_xticklabels(df_5_m.columns, rotation=75)
# Out:
# [Text(1, 0, '전체'),
#  Text(2, 0, '근로연령인구(18~65세)'),
#  Text(3, 0, '은퇴연령인구(66세 이상)'),
#  Text(4, 0, '노인인구(65세 이상)')]

# %%
df_7 = df_5_m[['근로연령인구(18~65세)']]
df_8 = df_5_f[['근로연령인구(18~65세)']]
df_9 = df_5_A[['근로연령인구(18~65세)']]

result = pd.concat([df_7,df_8], axis=1)
result.columns = ['근로연령 남자', '근로연령 여자']
result
# Out:
#         근로연령 남자  근로연령 여자
# 2011     3030.0   2890.0
# 2011.1   2795.0   2687.0
# 2012     3180.0   3039.0
# 2012.1   2926.0   2818.0
# 2013     3307.0   3163.0
# 2013.1   3055.0   2947.0
# 2014     3312.0   3181.0
# 2014.1   3057.0   2955.0
# 2015     3398.0   3293.0
# 2015.1   3117.0   3037.0
# 2016     3571.0   3421.0
# 2016.1   3266.0   3150.0
# 2017     3753.0   3612.0
# 2017.1   3413.0   3307.0
# 2018     3877.0   3747.0
# 2018.1   3513.0   3416.0
# 2019     3978.0   3862.0
# 2019.1   3620.0   3548.0
# 2020     4027.0   3923.0
# 2020.1   3735.0   3672.0
# 2021     4316.0   4214.0
# 2021.1   3978.0   3915.0

# %%
fig3 = plt.figure(figsize=(15, 7))
ax_1 = fig3.add_subplot(1, 2, 1)
ax_2 = fig3.add_subplot(1, 2, 2)

result.plot(ax=ax_1)
ax_1.set_title('성별별 소득 차이')

df_9.plot(ax=ax_2)
ax_2.set_title('연도별 소득 증감률')
# Out:
# Text(0.5, 1.0, '연도별 소득 증감률')

# %% [markdown]
# # 면적 그래프 그리기
# df_4.plot(kind='area', stacked=False, alpha=0.2, figsize=(20, 10))

# %%
df_6 = pd.read_csv('연도별 1인당 국민 총 소득.csv', index_col='Unnamed: 0')
df_6 = df_6.T
df3 = df_6[['1인당 실질 국민총소득(만 원)']]
df3['연도별 1인당 국민 총 소득(2020=100)'] = df3 * 10/353
df3.drop('1인당 실질 국민총소득(만 원)', axis=1, inplace=True)
# Out:
# C:\Users\dlwns\AppData\Local\Temp\ipykernel_16756\3175227384.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['연도별 1인당 국민 총 소득(2020=100)'] = df3 * 10/353
# C:\Users\dlwns\AppData\Local\Temp\ipykernel_16756\3175227384.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.drop('1인당 실질 국민총소득(만 원)', axis=1, inplace=True)

# %%
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

year = np.array(df4.index).reshape(-1, 1)
data = np.array(df4['한국']).reshape(-1, 1)

degree = 2  
poly_features = PolynomialFeatures(degree=degree)

year_poly = poly_features.fit_transform(year)

poly_reg = LinearRegression()
poly_reg.fit(year_poly, data)

list_1 = []
for i in range(6):
    prediction = poly_reg.predict(poly_features.transform([[i+2001]]))
    list_1.append(prediction)
list_1.append(poly_reg.predict(poly_features.transform([[2022]])))

list_1
# Out:
# [array([[70.88643354]]),
#  array([[70.18612123]]),
#  array([[69.73843992]]),
#  array([[69.54338962]]),
#  array([[69.60097031]]),
#  array([[69.91118201]]),
#  array([[109.23238536]])]

# %%
list_1_2d = [item[0] for item in list_1]

df5 = pd.DataFrame(list_1_2d[:6])
df6 = pd.DataFrame(list_1_2d[6])
df6

df4.columns = [0]

result1 = pd.concat([df5, df4, df6], axis=0)
result1.coloumns = '연도별 한국 가계부채율 (2020=100)'
a = []
for i in range(21):
    a.append(i+2002)
    
result1.index = a
result1
# Out:
#                0
# 2002   70.886434
# 2003   70.186121
# 2004   69.738440
# 2005   69.543390
# 2006   69.600970
# 2007   69.911182
# 2008   70.020222
# 2009   72.295248
# 2010   74.570273
# 2011   77.300303
# 2012   77.805865
# 2013   78.311426
# 2014   79.878665
# 2015   82.052578
# 2016   88.220425
# 2017   91.911021
# 2018   93.528817
# 2019   95.146613
# 2020  100.000000
# 2021  106.066734
# 2022  109.232385

# %%
result1.index = result1.index.astype(str)
result1.columns = ['가계부채 (2020=100)']

# %%
df1 = pd.read_csv('소비자 물가지수.csv', index_col='Unnamed: 0')
df2 = df1.iloc[0]

fig_ = plt.figure(figsize=(15, 7))
ax_3 = fig_.add_subplot(1, 1, 1)

df2.plot(kind='area', ax=ax_3, stacked=True, alpha=0.2)
df3.plot(kind='area', ax=ax_3 ,stacked=True, alpha=0.2)

df4 = pd.DataFrame(df_3)
df4 = df4 * 100/197.8

result1.plot(kind='area', ax=ax_3, stacked=True, alpha=0.2)
ax_3.legend(loc='upper left')

ax_3.set_ylim(40, 120)
# Out:
# (40.0, 120.0)
